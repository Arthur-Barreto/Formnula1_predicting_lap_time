# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
dados = pd.read_csv('fastest_laps_1950-2020.csv')

# %%
dados
# Out:
#       Unnamed: 0  Year             Venue                Name Driver Tag  \
# 0              0  1950     Great Britain         Nino Farina        FAR
# 1              1  1950            Monaco  Juan Manuel Fangio        FAN
# 2              2  1950  Indianapolis 500     Johnnie Parsons        PAR
# 3              3  1950       Switzerland         Nino Farina        FAR
# 4              4  1950           Belgium         Nino Farina        FAR
# ...          ...   ...               ...                 ...        ...
# 1030        1030  2020    Emilia Romagna      Lewis Hamilton        HAM
# 1031        1031  2020            Turkey        Lando Norris        NOR
# 1032        1032  2020           Bahrain      Max Verstappen        VER
# 1033        1033  2020            Sakhir      George Russell        RUS
# 1034        1034  2020         Abu Dhabi    Daniel Ricciardo        RIC
#
#                           Team  Lap Time
# 0                   Alfa Romeo  1:50.600
# ...
